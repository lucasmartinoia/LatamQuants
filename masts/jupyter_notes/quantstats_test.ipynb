# %%
# %matplotlib inline
import quantstats as qs

# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# fetch the daily returns for a stock
stock = qs.utils.download_returns('META')

# show sharpe ratio
qs.stats.sharpe(stock)

# or using extend_pandas() :)
stock.sharpe()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 0.6534013027336834

# %%
#qs.plots.snapshot(stock, title='Facebook Performance', show=True)
print(stock)
print(type(stock))
qs.reports.metrics(stock, "SPY", mode='full', display=False)
# Out:
# Date
# 2012-05-18         NaN
# 2012-05-21   -0.109861
# 2012-05-22   -0.089039
# 2012-05-23    0.032258
# 2012-05-24    0.032187
#                 ...
# 2023-09-11    0.032462
# 2023-09-12   -0.019183
# 2023-09-13    0.011271
# 2023-09-14    0.021832
# 2023-09-15   -0.036603
# Name: Close, Length: 2850, dtype: float64
# <class 'pandas.core.series.Series'>
# [*********************100%%**********************]  1 of 1 completed
#                   Benchmark (SPY)    Strategy
# Start Period           2012-05-21  2012-05-21
# End Period             2023-09-15  2023-09-15
# Risk-Free Rate                  0           0
# Time in Market                1.0         1.0
# Cumulative Return            2.36        7.82
# ...                           ...         ...
# Win Year                     0.75        0.75
# Beta                            -        1.24
# Alpha                           -        0.12
# Correlation                     -       0.52%
# ...

# %%
qs.reports.html(stock, "SPY", output='example_quantstats_report.html')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]

# %%
reporte

# %%
stock.plot_earnings()

# %%
[f for f in dir(qs.stats) if f[0] != '_']
# Out:
# ['adjusted_sortino',
#  'autocorr_penalty',
#  'avg_loss',
#  'avg_return',
#  'avg_win',
#  'best',
#  'cagr',
#  'calmar',
#  'common_sense_ratio',
#  'comp',
#  'compare',
#  'compsum',
#  'conditional_value_at_risk',
#  'consecutive_losses',
#  'consecutive_wins',
#  'cpc_index',
#  'cvar',
#  'distribution',
#  'drawdown_details',
#  'expected_return',
#  'expected_shortfall',
#  'exposure',
#  'gain_to_pain_ratio',
#  'geometric_mean',
#  'ghpr',
#  'greeks',
#  'implied_volatility',
#  'information_ratio',
#  'kelly_criterion',
#  'kurtosis',
#  'max_drawdown',
#  'monthly_returns',
#  'omega',
#  'outlier_loss_ratio',
#  'outlier_win_ratio',
#  'outliers',
#  'payoff_ratio',
#  'pct_rank',
#  'probabilistic_adjusted_sortino_ratio',
#  'probabilistic_ratio',
#  'probabilistic_sharpe_ratio',
#  'probabilistic_sortino_ratio',
#  'profit_factor',
#  'profit_ratio',
#  'r2',
#  'r_squared',
#  'rar',
#  'recovery_factor',
#  'remove_outliers',
#  'risk_of_ruin',
# ...

# %%
[f for f in dir(qs.plots) if f[0] != '_']
# Out:
# ['daily_returns',
#  'distribution',
#  'drawdown',
#  'drawdowns_periods',
#  'earnings',
#  'histogram',
#  'log_returns',
#  'monthly_heatmap',
#  'monthly_returns',
#  'plotly',
#  'returns',
#  'rolling_beta',
#  'rolling_sharpe',
#  'rolling_sortino',
#  'rolling_volatility',
#  'snapshot',
#  'to_plotly',
#  'warnings',
#  'yearly_returns']

# %%
[f for f in dir(qs.reports) if f[0] != '_']
# Out:
# ['StringIO',
#  'basic',
#  'full',
#  'html',
#  'iDisplay',
#  'iHTML',
#  'metrics',
#  'plots',
#  'relativedelta']

# %%
qs.reports.basic(stock, 'SPY')
#stock.metrics()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <h4>Performance Metrics</h4>
#                     Benchmark    Strategy
# ------------------  -----------  ----------
# Start Period        2012-05-22   2012-05-22
# End Period          2023-09-08   2023-09-08
# Risk-Free Rate      0.0%         0.0%
# Time in Market      100.0%       100.0%
#
# Cumulative Return   237.59%      775.37%
# CAGR﹪              7.71%        14.17%
#
# Sharpe              0.72         0.68
# Prob. Sharpe Ratio  99.12%       98.89%
# Sortino             1.0          1.0
# Sortino/√2          0.71         0.71
# Omega               1.14         1.14
#
# Max Drawdown        -34.1%       -76.74%
# Longest DD Days     613          731
#
# Gain/Pain Ratio     0.15         0.14
# Gain/Pain (1M)      0.9          0.77
#
# Payoff Ratio        0.9          0.98
# Profit Factor       1.15         1.14
# Common Sense Ratio  1.08         1.14
# CPC Index           0.57         0.58
# ...

# %%
reporte= qs.reports.full(stock, "SPY")
type(reporte)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2012-05-22   2012-05-22
# End Period                 2023-09-15   2023-09-15
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          235.96%      782.49%
# CAGR﹪                     7.67%        14.2%
#
# Sharpe                     0.71         0.68
# Prob. Sharpe Ratio         99.1%        98.9%
# Smart Sharpe               0.7          0.66
# Sortino                    1.0          1.01
# Smart Sortino              0.97         0.98
# Sortino/√2                 0.7          0.71
# Smart Sortino/√2           0.69         0.69
# Omega                      1.14         1.14
#
# Max Drawdown               -34.1%       -76.74%
# Longest DD Days            620          738
# ...
